# %% [markdown]
# <a href="https://colab.research.google.com/github/Sekharyavarna/Datascience-1/blob/main/Unemployment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reading the two datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
d1=pd.read_csv("Unemployment in India.csv")
d1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
d2=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")
d2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# # Dataset details

# %%
d1.info()
#this method tells us about no of non empty rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
d2.info()
#this method tells us about no of non empty rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
d1.describe()
# this method tells us about the statistical information of the data
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
d2.describe()
# this method tells us about the statistical information of the data
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
d1.isna().any()
# this method tells us about the null values
# Out:
# Region                                      True
#  Date                                       True
#  Frequency                                  True
#  Estimated Unemployment Rate (%)            True
#  Estimated Employed                         True
#  Estimated Labour Participation Rate (%)    True
# Area                                        True
# dtype: bool

# %%
d2.isna().any()
# this method tells us about the null values
# Out:
# Region                                      False
#  Date                                       False
#  Frequency                                  False
#  Estimated Unemployment Rate (%)            False
#  Estimated Employed                         False
#  Estimated Labour Participation Rate (%)    False
# Region.1                                    False
# longitude                                   False
# latitude                                    False
# dtype: bool

# %%
d1.fillna(0,inplace=True)
# this method fills the null values with zero

# %%
d1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763               0            0          0                              0.00
# 764               0            0          0                              0.00
# 765               0            0          0                              0.00
# 766               0            0          0                              0.00
# 767               0            0          0                              0.00
#
# ...

# %% [markdown]
# # Data analysis

# %%
plt.figure(figsize=(25,20))
sn.histplot(x=d2.columns[4],hue='Region',data=d2)
plt.title("Employment Rate in India")
plt.show()

# %%
plt.figure(figsize=(25,15))
sn.histplot(x=d2.columns[3],hue='Region',data=d2)
plt.title("Unemployment Rate in India")
plt.show()

# %%
#using heat map
sn.heatmap(d1.corr())
# Out:
# <ipython-input-14-612ccc976fab>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(d1.corr())
# <Axes: >

# %%
d2.drop(["longitude","latitude"],axis=1,inplace=True)
sn.heatmap(d2.corr())
# Out:
# <ipython-input-15-1fe08ef760cb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(d2.corr())
# <Axes: >

# %%
t=d2.groupby("Region")
t.mean()
# Out:
# <ipython-input-16-889945956802>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   t.mean()
#                    Estimated Unemployment Rate (%)   Estimated Employed  \
# Region
# Andhra Pradesh                            8.664000         1.542548e+07
# Assam                                     4.856000         1.081028e+07
# Bihar                                    19.471000         2.360683e+07
# Chhattisgarh                              7.819000         8.421349e+06
# Delhi                                    18.414000         4.632822e+06
# Goa                                      12.167000         4.423748e+05
# Gujarat                                   6.376000         2.273075e+07
# Haryana                                  27.477000         6.844059e+06
# ...

# %% [markdown]
# # Result:
#   Here the current Unemployment Rate,Employment Rate,Estimated Labour   Participation Rate is analysed and estimated.
